# %%
import os

# %%
files = [ x[:4] for x in os.listdir('./Generated CSV/')]

# %%
files2 = ['/home/saurabh/Downloads/wimp_corpus/wimp_corpus/annotations/'+x for x in os.listdir('/home/saurabh/Downloads/wimp_corpus/wimp_corpus/annotations/')]

# %%
nameFile = []

# %%
for x in files2:
    try:
        names = os.listdir(x)
        
        for x in names:
            nameFile.append(x)
    except:
        pass

nameFile
# Out:
# ['2565',
#  '.DS_Store',
#  '4021',
#  '4010',
#  '.DS_Store',
#  '4721',
#  '3044',
#  '3083',
#  '.DS_Store',
#  '4531',
#  '4320',
#  '2450',
#  '4400',
#  '.DS_Store',
#  '2222',
#  '2636',
#  '2886',
#  '2191',
#  '2348',
#  '3203',
#  '2710',
#  '3817',
#  '.DS_Store',
#  '2005',
#  '3301',
#  '3324',
#  '3601',
#  '2565',
#  '.DS_Store',
#  '4021',
#  '4010',
#  '.DS_Store',
#  '4721',
#  '3044',
#  '3083',
#  '.DS_Store',
#  '4531',
#  '4320',
#  '2450',
#  '4400',
#  '.DS_Store',
#  '2222',
#  '2636',
#  '2886',
#  '2191',
#  '2348',
#  '3203',
#  '2710',
#  '3817',
#  '.DS_Store',
#  '2005',
#  '3301',
#  '3324',
#  '3601',
#  '4021',
#  '4010',
#  '4721',
#  '4531',
#  '4400',
#  '2005',
#  '4021',
#  '4010',
#  '4721',
#  '4531',
#  '4400',
#  '2005',
#  '4021',
#  '4010',
#  '4721',
#  '4531',
#  '4400',
#  '2005',
#  '2565',
#  '4021',
#  '4010',
#  '4721',
#  '3044',
#  '3083',
#  '4531',
#  '4320',
#  '2450',
#  '4400',
#  '2222',
#  '2636',
#  '2886',
#  '2191',
# ...

# %%
count = 0
for x in files:
    if x in nameFile:
        count+=1
print(count)
# Out:
# 0

# %%
files
# Out:
# ['3311',
#  '4051',
#  '3367',
#  '2024',
#  '3369',
#  '3331',
#  '3584',
#  '3065',
#  '2041',
#  '3028',
#  '2040',
#  '2008',
#  '3563',
#  '4079',
#  '3382',
#  '2604',
#  '3364',
#  '3054',
#  '3325',
#  '3518',
#  '3041',
#  '2602',
#  '3344',
#  '3012',
#  '3514',
#  '4050',
#  '2631',
#  '4080',
#  '4019',
#  '2072',
#  '2586',
#  '2621',
#  '2667',
#  '2619',
#  '3570',
#  '3500',
#  '4048',
#  '2645',
#  '2039',
#  '4037',
#  '3057',
#  '2652',
#  '3338',
#  '3340',
#  '3061',
#  '2672',
#  '2647',
#  '3550',
#  '2078',
#  '3908',
#  '3508',
#  '3979',
#  '2603',
#  '2120',
#  '2038',
#  '3365',
#  '3009',
#  '3036',
#  '3064',
#  '3327',
#  '3359',
#  '3018',
#  '3040',
#  '3050',
#  '2663',
#  '3313',
#  '2648',
#  '3310',
#  '3993',
#  '4056',
#  '3595',
#  '3317',
#  '3379',
#  '4033']
